# %% [markdown]
# ### Python Enhancement Proposals - 8. Style Guide for Python Code
#
# https://peps.python.org/pep-0008/

# %% [markdown]
# <li>Használj 4 szóközt a behúzásokhoz (tabs) </li>
# <li>Korlátozd a sorokat 79 karakterre (72 karakter a dokumentációs sztringeknél). /Project-től függően ezt lehet állítani, e.g. nálunk 120 a limit.../</li>
# <li>Két üres sort használj a felső szintű függvények és osztályok elválasztásához.</li>
# <li>Egy üres sort használj a metódusok elválasztásához egy osztályon belül.</li>
# <br><li>A standard könyvtárakat importáld először, majd a harmadik féltől származó könyvtárakat, és végül a helyi importokat.</li>
# <li>Kerüld az extra szóközöket zárójelek, szögletes zárójelek és kapcsos zárójelek körül.</li>
# <li>Használj egyetlen szóközt a bináris operátorok körül (=, +, -, stb.).</li>
# <li>Használj kisbetűket alulvonásokkal a változónevekhez (snake_case). Függvények és metódusok esetén érdemes lehet úgy konstruálni az azonosítót hogy legyen benne ige. Például: get_something, set_value_field, calculate_taylor_approximation...</li>
# <br><li>Használj CamelCase-t az osztálynevekhez.</li>
# <li>Használj nagybetűs neveket alulvonásokkal a konstansokhoz (UPPER_SNAKE_CASE).</li>
# <li>Írj dokumentációs sztringeket minden nyilvános modulhoz, függvényhez, osztályhoz és metódushoz.</li>
# <li>None összehasonlításakor használj is és is not operátorokat.</li>
# <br><li>Kerüld a == vagy != használatát None-ra történő összehasonlításkor.</li>
# <li>Használj assert-ot hibakeresési célokra, ne adatellenőrzéshez.</li>
# <li>Kerüld a sorok végén lévő fölösleges szóközöket.</li>
# <li>Használj egyetlen üres sort a függvények definiálása előtt, kivéve az __init__ metódust osztályoknál.</li>
# <br><li>Csoportosítsd az összetartozó importokat, és válaszd el őket üres sorral. Például harmadik fél package-i és saját package importjai között 1 üres sor...</li>

# %% [markdown]
# ### Észrevételek:
#
# #### 1. Érdemes a változó, függvény, osztály nevekre figyelni
# #### 2. Az üres sorok, import, sor hosszúság stb... kevésbé lényeges, ezekre ott a Black Formatter extension
# #### 3. Legalább párat ezek közül illik tudni, mert simán interjú kérdés lehet egy olyan pozinál ahol Python kell...

# %%
from IPython.display import Image

Image(filename="resources/BlackFormatter.png")
